# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
flat=pd.read_csv('cleaned_flat.csv')
house=pd.read_csv('house_cleaned.csv')

# %%
flat.sample(5)
# Out:
#                            society price  area_persqft  \
# 135   sushant lok 1 builder floors   2.5       12920.0
# 2808               vidya apartment  0.22        4210.0
# 712                     paras dews  1.42        6029.0
# 2508             kashish manor one  1.65        7097.0
# 2816          m3m the tree of life  2.35       14551.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 135               Super Built up area 215(179.77 sq.m.)      3.0       3.0
# 2808  Built Up area: 570 (52.95 sq.m.)Carpet area: 5...      2.0       2.0
# 712              Super Built up area 2355(218.79 sq.m.)      4.0       6.0
# 2508                Super Built up area 2325(216 sq.m.)      3.0       4.0
# 2816                 Built Up area: 1615 (150.04 sq.m.)      3.0       3.0
#
#      balcony       additionalRoom  floorNum      facing        agePossession  \
# 135        2         not avilable       2.0         NaN      0 to 1 Year Old
# ...

# %%
house.sample(5)
# Out:
#                 society price  area_persqft                       area  \
# 867  vipul tatvam villa   8.2       25309.0      (301 sq.m.) Plot Area
# 230                 NaN   0.5        6083.0   (76 sq.m.) Built-up Area
# 983                 NaN  1.45       12393.0      (109 sq.m.) Plot Area
# 571                 NaN   3.5        9210.0  (353 sq.m.) Built-up Area
# 915  emaar mgf marbella  9.01       16066.0      (521 sq.m.) Plot Area
#
#                                           areaWithType  bedRoom  bathroom  \
# 867                        Plot area 360(301.01 sq.m.)      3.0       3.0
# 230  Built Up area: 822 (76.37 sq.m.)Carpet area: 7...      3.0       2.0
# 983  Plot area 130(108.7 sq.m.)Built Up area: 130 s...      4.0       4.0
# 571                 Built Up area: 3800 (353.03 sq.m.)      1.0       1.0
# 915                                      Plot area 521      4.0       4.0
#
#     balcony                      additionalRoom  noOfFloor      facing  \
# ...

# %%
house['type']='house'
flat['type']='flat'
flat['area']=flat['area'].apply(lambda val:str(val)+'sq-ft')

# %%
house.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
house.columns
# Out:
# Index(['society', 'price', 'area_persqft', 'area', 'areaWithType', 'bedRoom',
#        'bathroom', 'balcony', 'additionalRoom', 'floorNum', 'facing',
#        'agePossession', 'nearbyLocations', 'description', 'furnishDetails',
#        'features', 'sector', 'type'],
#       dtype='object')

# %%
gurgaon=pd.concat([flat, house], ignore_index=True)

# %%
gurgaon.shape
# Out:
# (4086, 18)

# %%
gurgaon.isnull().sum()
# Out:
# society             604
# price               112
# area_persqft         53
# areaWithType         92
# bedRoom              92
# bathroom             92
# balcony              92
# additionalRoom        0
# floorNum            113
# facing             1285
# agePossession        93
# nearbyLocations     260
# description          43
# furnishDetails     1141
# features            818
# sector                0
# area                  0
# type                  0
# dtype: int64

# %%
gurgaon.sample(5)
# Out:
#                   society price  area_persqft  \
# 3481       not applicable   0.4        9259.0
# 897           ats triumph   2.6        8813.0
# 1023        tata primanti   5.0       11363.0
# 3892                  NaN  15.0       33333.0
# 3764  smart world orchard  2.01       13000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3481                         Plot area 432(40.13 sq.m.)      1.0       1.0
# 897   Super Built up area 3150(292.64 sq.m.)Carpet a...      4.0       4.0
# 1023  Super Built up area 4400(408.77 sq.m.)Built Up...      4.0       4.0
# 3892                 Built Up area: 4500 (418.06 sq.m.)      4.0       4.0
# 3764                       Plot area 1549(143.91 sq.m.)      3.0       3.0
#
#      balcony                      additionalRoom  floorNum      facing  \
# 3481       1                        not avilable       1.0         NaN
# 897       3+                        Servant Room      16.0        East
# ...

# %%
gurgaon['sector'].value_counts()
# Out:
# sector
# sohna                                                        165
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    105
# sector 109                                                   103
# sector 69                                                     94
# sector 65                                                     91
# sector 81                                                     91
# sector 90                                                     90
# sector 79                                                     82
# sector 37d                                                    69
# sector 83                                                     69
# sector 86                                                     68
# sector 104                                                    67
# ...

# %%
gurgaon['sector'] = gurgaon['sector'].str.replace('dharam colony', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('krishna colony', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('suncity', 'sector 54')
gurgaon['sector'] = gurgaon['sector'].str.replace('prem nagar', 'sector 13')
gurgaon['sector'] = gurgaon['sector'].str.replace('mg road', 'sector 28')
gurgaon['sector'] = gurgaon['sector'].str.replace('gandhi nagar', 'sector 28')
gurgaon['sector'] = gurgaon['sector'].str.replace('laxmi garden', 'sector 11')
gurgaon['sector'] = gurgaon['sector'].str.replace('shakti nagar', 'sector 11')
gurgaon['sector'] = gurgaon['sector'].str.replace('baldev nagar', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('shivpuri', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('garhi harsaru', 'sector 17')
gurgaon['sector'] = gurgaon['sector'].str.replace('imt manesar', 'manesar')
gurgaon['sector'] = gurgaon['sector'].str.replace('adarsh nagar', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('shivaji nagar', 'sector 11')
gurgaon['sector'] = gurgaon['sector'].str.replace('bhim nagar', 'sector 6')
gurgaon['sector'] = gurgaon['sector'].str.replace('madanpuri', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('saraswati vihar', 'sector 28')
gurgaon['sector'] = gurgaon['sector'].str.replace('arjun nagar', 'sector 8')
gurgaon['sector'] = gurgaon['sector'].str.replace('ravi nagar', 'sector 9')
gurgaon['sector'] = gurgaon['sector'].str.replace('vishnu garden', 'sector 105')
gurgaon['sector'] = gurgaon['sector'].str.replace('bhondsi', 'sector 11')
gurgaon['sector'] = gurgaon['sector'].str.replace('surya vihar', 'sector 21')
gurgaon['sector'] = gurgaon['sector'].str.replace('devilal colony', 'sector 9')
gurgaon['sector'] = gurgaon['sector'].str.replace('valley view estate', 'gwal pahari')
gurgaon['sector'] = gurgaon['sector'].str.replace('mehrauli road', 'sector 14')
gurgaon['sector'] = gurgaon['sector'].str.replace('jyoti park', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('ansal plaza', 'sector 23')
gurgaon['sector'] = gurgaon['sector'].str.replace('dayanand colony', 'sector 6')
gurgaon['sector'] = gurgaon['sector'].str.replace('sushant lok phase 2', 'sector 55')
gurgaon['sector'] = gurgaon['sector'].str.replace('chakkarpur', 'sector 28')
gurgaon['sector'] = gurgaon['sector'].str.replace('greenwood city', 'sector 45')
gurgaon['sector'] = gurgaon['sector'].str.replace('subhash nagar', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('sohna road road', 'sohna road')
gurgaon['sector'] = gurgaon['sector'].str.replace('malibu town', 'sector 47')
gurgaon['sector'] = gurgaon['sector'].str.replace('surat nagar 1', 'sector 104')
gurgaon['sector'] = gurgaon['sector'].str.replace('new colony', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('mianwali colony', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('jacobpura', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('rajiv nagar', 'sector 13')
gurgaon['sector'] = gurgaon['sector'].str.replace('ashok vihar', 'sector 3')
gurgaon['sector'] = gurgaon['sector'].str.replace('dlf phase 1', 'sector 26')
gurgaon['sector'] = gurgaon['sector'].str.replace('nirvana country', 'sector 50')
gurgaon['sector'] = gurgaon['sector'].str.replace('palam vihar', 'sector 2')
gurgaon['sector'] = gurgaon['sector'].str.replace('dlf phase 2', 'sector 25')
gurgaon['sector'] = gurgaon['sector'].str.replace('sushant lok phase 1', 'sector 43')
gurgaon['sector'] = gurgaon['sector'].str.replace('laxman vihar', 'sector 4')
gurgaon['sector'] = gurgaon['sector'].str.replace('dlf phase 4', 'sector 28')
gurgaon['sector'] = gurgaon['sector'].str.replace('dlf phase 3', 'sector 24')
gurgaon['sector'] = gurgaon['sector'].str.replace('sushant lok phase 3', 'sector 57')
gurgaon['sector'] = gurgaon['sector'].str.replace('dlf phase 5', 'sector 43')
gurgaon['sector'] = gurgaon['sector'].str.replace('rajendra park', 'sector 105')
gurgaon['sector'] = gurgaon['sector'].str.replace('uppals southend', 'sector 49')
gurgaon['sector'] = gurgaon['sector'].str.replace('sohna', 'sohna road')
gurgaon['sector'] = gurgaon['sector'].str.replace('ashok vihar phase 3 extension', 'sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('south city 1', 'sector 41')
gurgaon['sector'] = gurgaon['sector'].str.replace('ashok vihar phase 2', 'sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 95a', 'sector 95')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 23a', 'sector 23')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 12a', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 3a', 'sector 3')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 110 a', 'sector 110')
gurgaon['sector'] = gurgaon['sector'].str.replace('patel nagar', 'sector 15')
gurgaon['sector'] = gurgaon['sector'].str.replace('a block sector 43', 'sector 43')
gurgaon['sector'] = gurgaon['sector'].str.replace('maruti kunj', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('b block sector 43', 'sector 43')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector-33 sohna road', 'sector 33')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 1 manesar', 'manesar')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 4 phase 2', 'sector 4')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 1a manesar', 'manesar')
gurgaon['sector'] = gurgaon['sector'].str.replace('c block sector 43', 'sector 43')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 89 a', 'sector 89')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 2 extension', 'sector 2')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 36 sohna road', 'sector 36')

# %% [raw]
# gurgaon['sector'].value_counts()

# %%
gurgaon['sector'] = gurgaon['sector'].str.replace('manesar', 'sector 1')
gurgaon['sector'] = gurgaon['sector'].str.replace('sohna road road', 'sohna road')
gurgaon['sector'] = gurgaon['sector'].str.replace('mehrauli  road', 'sector 14')
gurgaon['sector'] = gurgaon['sector'].str.replace('surat nagar', 'sector 104')
gurgaon['sector'] = gurgaon['sector'].str.replace('bhawani enclave', 'sector 9')

gurgaon['sector'] = gurgaon['sector'].str.replace('hira nagar','sector 11')

# %%
gurgaon['sector'].value_counts()
# Out:
# sector
# sohna road                                                   177
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    105
# sector 109                                                   103
# sector 69                                                     94
# sector 81                                                     91
# sector 65                                                     91
# sector 90                                                     90
# sector 79                                                     82
# sector 2                                                      81
# sector 104                                                    77
# sector 33                                                     76
# sector 43                                                     70
# ...

# %%
gurgaon['sector'] = gurgaon['sector'].str.replace('sheetla colony','sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 12 near sadar bazar', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 3 phase 3', 'sector 3')
gurgaon['sector'] = gurgaon['sector'].str.replace('new sector 7', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('mahasector 11, rajendra place', 'sector 11')
gurgaon['sector'] = gurgaon['sector'].str.replace("ansal's sector 2", 'sector 2')
gurgaon['sector'] = gurgaon['sector'].str.replace('sadar bazar', 'Sadar Bazar')
gurgaon['sector'] = gurgaon['sector'].str.replace('damdma', 'Damdama')
gurgaon['sector'] = gurgaon['sector'].str.replace('naharpur rupa', 'Naharpur Rupa')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector-5 sheetla colony', 'sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 4, railway road', 'sector 4')
gurgaon['sector'] = gurgaon['sector'].str.replace('udyog vihar phase 1', 'Udyog Vihar Phase 1')
gurgaon['sector'] = gurgaon['sector'].str.replace('rattan garden', 'Rattan Garden')
gurgaon['sector'] = gurgaon['sector'].str.replace('shivji park colony', 'Shivji Park Colony')
gurgaon['sector'] = gurgaon['sector'].str.replace('mahavir pura near sector 1 market', 'Mahavir Pura')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 37b', 'sector 37B')
gurgaon['sector'] = gurgaon['sector'].str.replace('v block sector 24', 'sector 24')
gurgaon['sector'] = gurgaon['sector'].str.replace('south city', 'South City')

gurgaon['sector'] = gurgaon['sector'].str.replace('b1 block sector 57', 'sector 57')
gurgaon['sector'] = gurgaon['sector'].str.replace('sultanpur', 'Sultanpur')
gurgaon['sector'] = gurgaon['sector'].str.replace('heritage city', 'Heritage City')
gurgaon['sector'] = gurgaon['sector'].str.replace('laxmna vihar, phase 2', 'Laxman Vihar')
gurgaon['sector'] = gurgaon['sector'].str.replace('huda sector 28', 'sector 28')

gurgaon['sector'] = gurgaon['sector'].str.replace('bhimgarh kheri phase 3', 'Bhimgarh Kheri Phase 3')
gurgaon['sector'] = gurgaon['sector'].str.replace('near euro', 'Near Euro')
gurgaon['sector'] = gurgaon['sector'].str.replace('sec 3 bhim vihar part 1 bhimgher kheri', 'Sec 3 Bhim Vihar Part 1 Bhimgarh Kheri')
gurgaon['sector'] = gurgaon['sector'].str.replace('saraswati enclave', 'Saraswati Enclave')
gurgaon['sector'] = gurgaon['sector'].str.replace('alipur', 'Alipur')
gurgaon['sector'] = gurgaon['sector'].str.replace('devi lal colony gali no 12 gurgaon nr omkar public school', 'Devi Lal Colony')
gurgaon['sector'] = gurgaon['sector'].str.replace('anand garden, sector-105', 'Anand Garden')
gurgaon['sector'] = gurgaon['sector'].str.replace('dhankot', 'Dhankot')
gurgaon['sector'] = gurgaon['sector'].str.replace('begampur khatola', 'Begampur Khatola')
gurgaon['sector'] = gurgaon['sector'].str.replace('ravi nager basai road', 'Ravi Nagar Basai Road')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 12 block e', 'sector 12')
gurgaon['sector'] = gurgaon['sector'].str.replace('park view', 'Park View')

gurgaon['sector'] = gurgaon['sector'].str.replace('g block dlf city phase 1', 'G Block DLF City Phase 1')
gurgaon['sector'] = gurgaon['sector'].str.replace('tekchand nagar', 'Tekchand Nagar')
gurgaon['sector'] = gurgaon['sector'].str.replace('lucknow', 'Lucknow')
gurgaon['sector'] = gurgaon['sector'].str.replace('om nagar', 'Om Nagar')
gurgaon['sector'] = gurgaon['sector'].str.replace('block g sector-57', 'G Block Sector 57')
gurgaon['sector'] = gurgaon['sector'].str.replace('gopal nagar, garhi ghasita, sonipat', 'Gopal Nagar, Garhi Ghasita, Sonipat')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 17c', 'sector 17C')
gurgaon['sector'] = gurgaon['sector'].str.replace('hsiidc plot sector 1', 'HSIIDC Plot Sector 1')


gurgaon['sector'] = gurgaon['sector'].str.replace('sector-35 sohna road', '35 Sohna Road')

gurgaon['sector'] = gurgaon['sector'].str.replace('garauli kalan', 'Garauli Kalan')
gurgaon['sector'] = gurgaon['sector'].str.replace('old delhi road, opp sector-14', 'Sector-14')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 5 chowk', 'sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector-5 sohna road', '5 Sohna Road')
gurgaon['sector'] = gurgaon['sector'].str.replace('carterpuri village', 'Carterpuri Village')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 37a', 'sector 37')
gurgaon['sector'] = gurgaon['sector'].str.replace('ats marigold', 'ATS Marigold')
gurgaon['sector'] = gurgaon['sector'].str.replace('cyber city', 'Cyber City')
gurgaon['sector'] = gurgaon['sector'].str.replace('jat colony,fazilpur/taj nagar road', 'Jat Colony, Fazilpur/Taj Nagar Road')
gurgaon['sector'] = gurgaon['sector'].str.replace('kanahi', 'Kanahi')
gurgaon['sector'] = gurgaon['sector'].str.replace('kheri', 'Kheri')
gurgaon['sector'] = gurgaon['sector'].str.replace('part 3 sector 5', 'Sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('ram nagar', 'Ram Nagar')
gurgaon['sector'] = gurgaon['sector'].str.replace('hno 13 sagar enclave sura', '13 Sagar Enclave Sura')
gurgaon['sector'] = gurgaon['sector'].str.replace('vir nagar', 'Vir Nagar')
gurgaon['sector'] = gurgaon['sector'].str.replace('heera nagar', 'Heera Nagar')
gurgaon['sector'] = gurgaon['sector'].str.replace('dhunela', 'Dhunela')
gurgaon['sector'] = gurgaon['sector'].str.replace('anand garden, sector-105 gurgaon', 'Anand Garden, Sector-105 Gurgaon')
gurgaon['sector'] = gurgaon['sector'].str.replace('pataudi road', 'Pataudi Road')
gurgaon['sector'] = gurgaon['sector'].str.replace('civil l near pataudi chowk', 'Civil L Near Pataudi Chowk')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector-7 hous', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('near khandsa road', 'Near Khandsa Road')
gurgaon['sector'] = gurgaon['sector'].str.replace('urban estate, sector 5', 'Urban Estate, Sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('khandsa', 'Khandsa')
gurgaon['sector'] = gurgaon['sector'].str.replace('sai kunj', 'Sai Kunj')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 3 phase i', 'sector 3 ')
gurgaon['sector'] = gurgaon['sector'].str.replace('near nand hospital', 'Near Nand Hospital')
gurgaon['sector'] = gurgaon['sector'].str.replace('bhora kalan', 'sector 9b')
                                                  
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 9b', 'sector 9')

# %%
gurgaon['sector'].value_counts()
# Out:
# sector
# sohna road                                177
# sector 102                                113
# sector 85                                 110
# sector 92                                 105
# sector 109                                103
# sector 69                                  94
# sector 81                                  91
# sector 65                                  91
# sector 90                                  90
# sector 2                                   82
# sector 79                                  82
# sector 104                                 77
# sector 33                                  76
# sector 43                                  70
# sector 83                                  69
# sector 95                                  69
# sector 37d                                 69
# sector 86                                  68
# sector 50                                  66
# sector 48                                  66
# ...

# %%
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 7, sector 7', 'sector 7')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector 17C', 'sector 17')
gurgaon['sector'] = gurgaon['sector'].str.replace('saroop garden sector 105', 'sector 105')
gurgaon['sector'] = gurgaon['sector'].str.replace('sector-5 sector 5', 'sector 5')
gurgaon['sector'] = gurgaon['sector'].str.replace('block a sector 21', 'sector 21b')
gurgaon['sector'] = gurgaon['sector'].str.replace('godrej aria , sector 79 ', 'sector 79')
gurgaon['sector'] = gurgaon['sector'].str.replace('block a sector 21', 'sector 21b')
gurgaon['sector'] = gurgaon['sector'].str.replace('block a sector 21', 'sector 21b')

# %%
gurgaon['sector'].value_counts()
# Out:
# sector
# sohna road                                177
# sector 102                                113
# sector 85                                 110
# sector 92                                 105
# sector 109                                103
# sector 69                                  94
# sector 81                                  91
# sector 65                                  91
# sector 90                                  90
# sector 2                                   82
# sector 79                                  82
# sector 104                                 77
# sector 33                                  76
# sector 43                                  70
# sector 83                                  69
# sector 95                                  69
# sector 37d                                 69
# sector 86                                  68
# sector 50                                  66
# sector 48                                  66
# ...

# %%
gurgaon[(gurgaon['sector']=='nars')|(gurgaon['sector']=='new')|(gurgaon['sector']==', delhi ncr')]
# Out:
#                            society price  area_persqft  \
# 2048                        dlf 76   4.0       11428.0
# 2810  takshila heights sector 37 c  0.67        5583.0
# 2906                   green court  0.38        5507.0
# 2979                    sare homes  0.85        4786.0
# 3067                     sector 37  0.55        7290.0
# 3530                           NaN   0.5        3704.0
# 3561                           NaN   1.5       16667.0
# 3772                           NaN  0.53       63554.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2048                   Carpet area: 3500 (325.16 sq.m.)      4.0       4.0
# 2810             Super Built up area 1200(111.48 sq.m.)      2.0       2.0
# 2906                      Carpet area: 690 (64.1 sq.m.)      2.0       2.0
# 2979                Super Built up area 1776(165 sq.m.)      4.0       4.0
# 3067  Plot area 84(70.23 sq.m.)Built Up area: 83 sq....      2.0       1.0
# ...

# %%
ind=gurgaon[(gurgaon['sector']=='nars')|(gurgaon['sector']=='new')|(gurgaon['sector']==', delhi ncr')].index
gurgaon.drop(list(ind),axis=0,inplace=True)

# %%
gurgaon['sector'].value_counts()
# Out:
# sector
# sohna road                                177
# sector 102                                113
# sector 85                                 110
# sector 92                                 105
# sector 109                                103
# sector 69                                  94
# sector 81                                  91
# sector 65                                  91
# sector 90                                  90
# sector 2                                   82
# sector 79                                  82
# sector 104                                 77
# sector 33                                  76
# sector 43                                  70
# sector 37d                                 69
# sector 95                                  69
# sector 83                                  69
# sector 86                                  68
# sector 50                                  66
# sector 48                                  66
# ...

# %%
gurgaon['sector']=gurgaon['sector'].str

# %% [raw]
# df.loc[955,'sector'] = 'sector 37'
# df.loc[2800,'sector'] = 'sector 92'
# df.loc[2838,'sector'] = 'sector 90'
# df.loc[2857,'sector'] = 'sector 76'
# df[df['sector'] == 'new sector 2']

# %% [raw]
# df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'
