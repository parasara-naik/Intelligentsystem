# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
original_df=pd.read_csv('gurgaon_cleaned.csv')

# %%
df=pd.read_csv('eda_ready.csv')

# %%
original_df.sample(5)
# Out:
#                    society price  area_persqft  \
# 2466    sare crescent parc  0.49        4909.0
# 2284            rof ananda  0.55        8527.0
# 1115      ss the coralwood  1.01        5771.0
# 362   emaar gurgaon greens  1.42        8606.0
# 1850  shree vardhman flora  0.65        4814.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2466                     Carpet area: 998 (92.72 sq.m.)      2.0       2.0
# 2284  Super Built up area 1000(92.9 sq.m.)Carpet are...      3.0       2.0
# 1115  Super Built up area 1750(162.58 sq.m.)Built Up...      3.0       3.0
# 362   Super Built up area 1650(153.29 sq.m.)Carpet a...      3.0       3.0
# 1850             Super Built up area 1350(125.42 sq.m.)      2.0       2.0
#
#      balcony additionalRoom  floorNum      facing    agePossession  \
# 2466       2   not avilable       2.0         NaN  1 to 5 Year Old
# 2284       2     Study Room      14.0        East  0 to 1 Year Old
# ...

# %%
original_df[original_df['area_persqft']==600000]
# Out:
#                      society price  area_persqft                areaWithType  \
# 3686  emaar the palm springs  24.0      600000.0  Plot area 400(37.16 sq.m.)
#
#       bedRoom  bathroom balcony                      additionalRoom  floorNum  \
# 3686      5.0       5.0       2  Pooja Room,Study Room,Servant Room       1.0
#
#           facing agePossession  \
# 3686  North-East  10+ Year Old
#
#                                         nearbyLocations  \
# 3686  ['Sector 53-54 Metro Station', 'Central Plaza ...
#
#                                             description  \
# 3686  Emaar palm spring sector-54 (Villa) 400 gaj ba...
#
#                                          furnishDetails  \
# 3686  ['8 Fan', '1 Exhaust Fan', '7 Geyser', '32 Lig...
#
#                                                features     sector  \
# 3686  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...  sector 54
#
#                       area   type
# 3686  (37 sq.m.) Plot Area  house

# %% [raw]
# 3272    8711260.000 error found

# %%
original_df.loc[3272][['areaWithType','area','type']]
# Out:
# areaWithType    Built Up area: 3500 (325.16 sq.m.)Carpet area:...
# area                                    (325 sq.m.) Built-up Area
# type                                                        house
# Name: 3272, dtype: object

# %%
original_df.loc[3272]['areaWithType']
# Out:
# 'Built Up area: 3500 (325.16 sq.m.)Carpet area: 2500 sq.ft. (232.26 sq.m.)'

# %%
df.loc[3272]
# Out:
# society                                    NaN
# price                                     1.35
# price_persqft                           3857.0
# bedRoom                                    5.0
# bathroom                                   3.0
# balcony                                      3
# floorNum                                   3.0
# facing                                    East
# agePossession                        Undefined
# sector                              sector 105
# area                 (325 sq.m.) Built-up Area
# type                                     house
# super_bulituparea                          NaN
# built_uparea                            3500.0
# carpet_area                             2500.0
# study room                                   0
# servant room                                 0
# store room                                   0
# pooja room                                   0
# others                                       0
# ...

# %%
df.loc[[3272,3273,3271]]
# Out:
#      society price  price_persqft  bedRoom  bathroom balcony  floorNum facing  \
# 3272     NaN  1.35         3857.0      5.0       3.0       3       3.0   East
# 3273     NaN   4.7        21759.0      3.0       3.0       2       2.0  North
# 3271     NaN   NaN            NaN      6.0       4.0       2       2.0   East
#
#        agePossession      sector                       area   type  \
# 3272       Undefined  sector 105  (325 sq.m.) Built-up Area  house
# 3273    Old Property   sector 57      (201 sq.m.) Plot Area  house
# 3271  Moderately Old   sector 11      (251 sq.m.) Plot Area  house
#
#       super_bulituparea  built_uparea  carpet_area  study room  servant room  \
# 3272                NaN        3500.0       2500.0           0             0
# 3273                NaN        2160.0          NaN           0             0
# 3271                NaN        2700.0          NaN           0             0
#
#       store room  pooja room  others  furnishing_type  luxury_score
# ...

# %%
df.loc[3272,'area']=3498.27
df.loc[3272,'built_up_area']=3500
df.loc[3272,'carpet_area']=2500

# %%
2447     875000.000
114      642857.143
1308     620000.000
1971     566666.667
3438     215949.000
3406      82789.000

# %%
original_df.loc[[2447,114,1308,1971,3438,3406]]
# Out:
#                         society price  area_persqft  \
# 2447          hcbs sports ville  0.35           4.0
# 114       signature the roselia  0.45           7.0
# 1308            ramsons kshitij  0.31           5.0
# 1971  signature global solera 2  0.51           9.0
# 3438        shree krishna homes  0.48       50000.0
# 3406         vipul tatvam villa   8.5       26235.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2447              Built Up area: 737147 (68483.2 sq.m.)      2.0       2.0
# 114                Carpet area: 569243 (52884.41 sq.m.)      2.0       2.0
# 1308                Carpet area: 607936 (56479.1 sq.m.)      2.0       2.0
# 1971               Carpet area: 514396 (47788.95 sq.m.)      2.0       2.0
# 3438  Plot area 80(7.43 sq.m.)Built Up area: 795 sq....      2.0       2.0
# 3406                        Plot area 360(301.01 sq.m.)      4.0       6.0
#
#      balcony                  additionalRoom  floorNum      facing  \
# ...

# %%
original_df.loc[3438]['areaWithType']
# Out:
# 'Plot area 80(7.43 sq.m.)Built Up area: 795 sq.ft. (73.86 sq.m.)Carpet area: 720 sq.ft. (66.89 sq.m.)'

# %%
df.loc[3438,'built_uparea']=795

# %% [markdown]
# On average, the carpet area is around 70% of the built-up area.

# %%
df.sample(5)
# Out:
#                          society price  price_persqft  bedRoom  bathroom  \
# 1637               tata primanti   3.5        11428.0      4.0       5.0
# 2619          dlf royalton tower   6.2        20687.0      4.0       4.0
# 766          experion windchants  3.75        13383.0      3.0       5.0
# 2558  central park flower valley   1.4        21538.0      3.0       3.0
# 3966                         NaN  2.35        16319.0      4.0       4.0
#
#      balcony  floorNum      facing       agePossession      sector  \
# 1637      3+      16.0        East      Relatively New   sector 72
# 2619      3+       9.0         NaN      Moderately Old   sector 43
# 766       3+      22.0  South-West      Relatively New  sector 112
# 2558       3       2.0         NaN  Under Construction   sector 33
# 3966       2       2.0        East        Old Property    sector 4
#
#                        area   type  super_bulituparea  built_uparea  \
# ...

# %%
2447    737147.0
3227     26000.0
3147     13500.0
3456     12000.0
3709     11286.0
3990      9500.0
3961      9000.0
3900      9000.0
3683      9000.0
3862      9000.0

# %%
original_df.loc[[2447,3227,3147,3456,3709,3990,3961,3900,3683,3862]]['areaWithType']
# Out:
# 2447                Built Up area: 737147 (68483.2 sq.m.)
# 3227                     Carpet area: 2800 (260.13 sq.m.)
# 3147    Plot area 2400(222.97 sq.m.)Built Up area: 340...
# 3456                            Plot area 50(41.81 sq.m.)
# 3709                          Plot area 350(292.64 sq.m.)
# 3990                          Plot area 189(158.03 sq.m.)
# 3961                          Plot area 192(160.54 sq.m.)
# 3900    Plot area 1530(142.14 sq.m.)Built Up area: 190...
# 3683                          Plot area 173(144.65 sq.m.)
# 3862                          Plot area 161(134.62 sq.m.)
# Name: areaWithType, dtype: object

# %%
original_df.loc[3147]['areaWithType']
# Out:
# 'Plot area 2400(222.97 sq.m.)Built Up area: 3400 sq.ft. (315.87 sq.m.)Carpet area: 3000 sq.ft. (278.71 sq.m.)'

# %%
df.loc[3900,'built_uparea']=1900

# %%
df.loc[3227,'built_uparea']=4000
df.loc[3147,'built_uparea']=3400
